# %%
from __future__ import print_function, unicode_literals, absolute_import, division
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

from glob import glob
from tqdm import tqdm
from tifffile import imread
from csbdeep.utils import Path, normalize
from stardist import fill_label_holes, random_label_cmap

np.random.seed(42)
#lbl_cmap = random_label_cmap()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data
#
# We assume that data has already been downloaded in via notebook [1_data.ipynb](1_data.ipynb).
# In general, training data (for input `X` with associated labels `Y`) can be provided via lists of numpy arrays, where each image can have a different size. Alternatively, a single numpy array can also be used if all images have the same size.
# Input images can either be two-dimensional (single-channel) or three-dimensional (multi-channel) arrays, where the channel axis comes last. Label images need to be integer-valued.

# %%
X = sorted(glob('data/dsb2018/train/images/*.tif'))
Y = sorted(glob('data/dsb2018/train/masks/*.tif'))
assert all(Path(x).name==Path(y).name for x,y in zip(X,Y))

# %%
X = list(map(imread,X))
Y = list(map(imread,Y))
n_channel = 1 if X[0].ndim == 2 else X[0].shape[-1]

# %% [markdown]
# Normalize images and fill small label holes.

# %%
axis_norm = (0,1)   # normalize channels independently
# axis_norm = (0,1,2) # normalize channels jointly
if n_channel > 1:
    print("Normalizing image channels %s." % ('jointly' if axis_norm is None or 2 in axis_norm else 'independently'))
    sys.stdout.flush()

X = [normalize(x,1,99.8,axis=axis_norm) for x in tqdm(X)]
Y = [fill_label_holes(y) for y in tqdm(Y)]
# Out:
# 100%|██████████| 447/447 [00:00<00:00, 610.17it/s]
# 100%|██████████| 447/447 [00:02<00:00, 161.82it/s]

# %%
rng = np.random.RandomState(42)
ind = rng.permutation(len(X))
n_val = int(round(0.15 * len(X)))
ind_train, ind_val = ind[:-n_val], ind[-n_val:]
X_val, Y_val = [X[i][:256,:256,np.newaxis] for i in ind_val]  , [Y[i][:256,:256,np.newaxis] for i in ind_val]
X_trn, Y_trn = [X[i][:256,:256,np.newaxis] for i in ind_train], [Y[i][:256,:256,np.newaxis] for i in ind_train] 
print('number of images: %3d' % len(X))
print('- training:       %3d' % len(X_trn))
print('- validation:     %3d' % len(X_val))
# Out:
# number of images: 447
# - training:       380
# - validation:      67

# %%
#https://segmentation-models.readthedocs.io/en/latest/tutorial.html
from segmentation_models import Unet
from segmentation_models.backbones import get_preprocessing
from segmentation_models.losses import bce_jaccard_loss
from segmentation_models.metrics import iou_score
from keras.layers import Input, Conv2D
from keras.models import Model
from keras.utils import multi_gpu_model

BACKBONE = 'resnet34'
preprocess_input = get_preprocessing(BACKBONE)

# load your data
x_train = np.stack(X_trn,axis=0)
y_train = np.stack(Y_trn,axis=0)
x_val = np.stack(X_val,axis=0)
y_val = np.stack(Y_val,axis=0)

# %%
# preprocess input
x_train = preprocess_input(x_train)
x_val = preprocess_input(x_val)

# define model
#base_model = Unet(BACKBONE, encoder_weights='imagenet')

# mitigating greyscale images
#inp = Input(shape=(None, None, 1))
#l1 = Conv2D(3, (1, 1))(inp) # map 1 channel onto 3 channels through a conv with 1x1 and 3 filters
#out = base_model(l1)

#kmodel = Model(inp, out, name=base_model.name)
#kmodel = multi_gpu_model(model, gpus=2)
kmodel = Unet(BACKBONE, encoder_weights=None, input_shape=(None, None, 1))

kmodel.compile('Adam', loss=bce_jaccard_loss, metrics=[iou_score])
print(kmodel.output)
# Out:
# Tensor("sigmoid_3/Sigmoid:0", shape=(?, ?, ?, 1), dtype=float32)

# %%
# fit model
# if you use data generator use model.fit_generator(...) instead of model.fit(...)
# more about `fit_generator` here: https://keras.io/models/sequential/#fit_generator
kmodel.fit(
    x=x_train,
    y=y_train,
    batch_size=16,
    epochs=100,
    validation_data=(x_val, y_val),
)
# Out:
# Train on 380 samples, validate on 67 samples
# Epoch 1/100
# 380/380 [==============================] - 27s 71ms/step - loss: -19.3803 - iou_score: 4.2249 - val_loss: -30.5589 - val_iou_score: 2.4794
# Epoch 2/100
# 380/380 [==============================] - 4s 11ms/step - loss: -41.6815 - iou_score: 7.5266 - val_loss: -12.7770 - val_iou_score: 1.3163
# Epoch 3/100
# 380/380 [==============================] - 4s 11ms/step - loss: -58.8930 - iou_score: 10.2947 - val_loss: 22.9223 - val_iou_score: 1.2522
# Epoch 4/100
# 380/380 [==============================] - 4s 11ms/step - loss: -70.7320 - iou_score: 12.2119 - val_loss: -6.6250 - val_iou_score: 3.8378
# Epoch 5/100
# 380/380 [==============================] - 4s 11ms/step - loss: -73.0629 - iou_score: 12.8359 - val_loss: 47.5598 - val_iou_score: 0.0277
# Epoch 6/100
# 380/380 [==============================] - 4s 11ms/step - loss: -74.2286 - iou_score: 13.1237 - val_loss: 19.0896 - val_iou_score: 0.4591
# Epoch 7/100
# 380/380 [==============================] - 4s 11ms/step - loss: -74.3716 - iou_score: 13.3220 - val_loss: -52.1896 - val_iou_score: 10.5737
# Epoch 8/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.3378 - iou_score: 13.7751 - val_loss: -54.4379 - val_iou_score: 11.8517
# Epoch 9/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.4294 - iou_score: 13.9919 - val_loss: -54.7031 - val_iou_score: 11.9029
# Epoch 10/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.2901 - iou_score: 13.8620 - val_loss: -55.3330 - val_iou_score: 11.9906
# Epoch 11/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.8647 - iou_score: 14.2262 - val_loss: -54.7411 - val_iou_score: 11.7585
# Epoch 12/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.6695 - iou_score: 13.9138 - val_loss: -55.3492 - val_iou_score: 11.4900
# Epoch 13/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.2520 - iou_score: 14.3776 - val_loss: -56.0344 - val_iou_score: 11.9657
# Epoch 14/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.9340 - iou_score: 14.1555 - val_loss: -56.5429 - val_iou_score: 12.4901
# Epoch 15/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.9469 - iou_score: 14.0497 - val_loss: -56.3365 - val_iou_score: 12.3444
# Epoch 16/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.8804 - iou_score: 14.1235 - val_loss: -56.1650 - val_iou_score: 11.9535
# Epoch 17/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.7697 - iou_score: 14.1669 - val_loss: -56.5161 - val_iou_score: 12.3692
# Epoch 18/100
# 380/380 [==============================] - 4s 11ms/step - loss: -75.8094 - iou_score: 14.0701 - val_loss: -10.7340 - val_iou_score: 5.6539
# Epoch 19/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.1040 - iou_score: 14.1650 - val_loss: -56.7271 - val_iou_score: 12.4495
# Epoch 20/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.4447 - iou_score: 14.4891 - val_loss: -40.3555 - val_iou_score: 9.4495
# Epoch 21/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.1603 - iou_score: 14.2180 - val_loss: -56.4330 - val_iou_score: 12.1607
# Epoch 22/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.7444 - iou_score: 14.7014 - val_loss: -56.5012 - val_iou_score: 12.7207
# Epoch 23/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.4646 - iou_score: 14.4699 - val_loss: -56.7529 - val_iou_score: 12.4874
# Epoch 24/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.9775 - iou_score: 14.9711 - val_loss: -57.0908 - val_iou_score: 12.8460
# Epoch 25/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.7414 - iou_score: 14.7688 - val_loss: -56.3914 - val_iou_score: 12.5538
# Epoch 26/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.6042 - iou_score: 14.5185 - val_loss: -57.1270 - val_iou_score: 12.9100
# Epoch 27/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.9909 - iou_score: 14.9411 - val_loss: -57.5532 - val_iou_score: 13.2296
# Epoch 28/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.9186 - iou_score: 14.8002 - val_loss: -57.4578 - val_iou_score: 13.1572
# Epoch 29/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.1363 - iou_score: 15.0182 - val_loss: -57.0072 - val_iou_score: 12.7618
# Epoch 30/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.2941 - iou_score: 14.3772 - val_loss: -56.5142 - val_iou_score: 12.8067
# Epoch 31/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.9858 - iou_score: 14.9262 - val_loss: -56.8869 - val_iou_score: 12.7248
# Epoch 32/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.0325 - iou_score: 14.9210 - val_loss: -57.3231 - val_iou_score: 13.1102
# Epoch 33/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.0869 - iou_score: 14.9201 - val_loss: -57.5980 - val_iou_score: 13.3462
# Epoch 34/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.9323 - iou_score: 14.9110 - val_loss: -56.8057 - val_iou_score: 12.6049
# Epoch 35/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.3184 - iou_score: 15.1575 - val_loss: -56.9265 - val_iou_score: 13.0965
# Epoch 36/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.1805 - iou_score: 15.0730 - val_loss: -56.4146 - val_iou_score: 12.8171
# Epoch 37/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.0406 - iou_score: 14.9617 - val_loss: -57.4241 - val_iou_score: 13.1506
# Epoch 38/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.1434 - iou_score: 15.0688 - val_loss: -57.3783 - val_iou_score: 13.1328
# Epoch 39/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.8220 - iou_score: 14.8956 - val_loss: -55.8656 - val_iou_score: 12.6918
# Epoch 40/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.4795 - iou_score: 15.2541 - val_loss: -57.4191 - val_iou_score: 13.1605
# Epoch 41/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.8685 - iou_score: 14.7978 - val_loss: -57.4516 - val_iou_score: 13.2582
# Epoch 42/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.1670 - iou_score: 15.1084 - val_loss: -47.1489 - val_iou_score: 11.3788
# Epoch 43/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.0947 - iou_score: 15.0258 - val_loss: -57.6654 - val_iou_score: 13.3183
# Epoch 44/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.4279 - iou_score: 15.2600 - val_loss: -52.2140 - val_iou_score: 12.1572
# Epoch 45/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.0190 - iou_score: 14.8963 - val_loss: -57.2875 - val_iou_score: 13.1670
# Epoch 46/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.1550 - iou_score: 15.0237 - val_loss: -57.5968 - val_iou_score: 13.2640
# Epoch 47/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.3249 - iou_score: 15.2009 - val_loss: -57.3511 - val_iou_score: 13.0074
# Epoch 48/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.4165 - iou_score: 15.2487 - val_loss: -56.2175 - val_iou_score: 12.7285
# Epoch 49/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.3362 - iou_score: 15.1920 - val_loss: -57.6253 - val_iou_score: 13.3148
# Epoch 50/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.3209 - iou_score: 15.1405 - val_loss: -57.0416 - val_iou_score: 12.7913
# Epoch 51/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.2700 - iou_score: 15.1334 - val_loss: -56.3437 - val_iou_score: 12.7367
# Epoch 52/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.5826 - iou_score: 15.3811 - val_loss: -38.7080 - val_iou_score: 8.8703
# Epoch 53/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.7300 - iou_score: 15.4189 - val_loss: -31.9569 - val_iou_score: 7.3844
# Epoch 54/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.4401 - iou_score: 15.2838 - val_loss: -57.1492 - val_iou_score: 13.0575
# Epoch 55/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.7577 - iou_score: 15.4690 - val_loss: -57.4667 - val_iou_score: 13.2072
# Epoch 56/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.2931 - iou_score: 15.2193 - val_loss: -52.2294 - val_iou_score: 9.9008
# Epoch 57/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.3674 - iou_score: 15.1999 - val_loss: -36.5039 - val_iou_score: 6.2350
# Epoch 58/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.2309 - iou_score: 15.1294 - val_loss: -36.2290 - val_iou_score: 7.7282
# Epoch 59/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.2360 - iou_score: 15.0819 - val_loss: -56.8862 - val_iou_score: 13.0278
# Epoch 60/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.0020 - iou_score: 14.9380 - val_loss: -56.3357 - val_iou_score: 12.5694
# Epoch 61/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.1603 - iou_score: 15.0127 - val_loss: -57.0531 - val_iou_score: 12.8163
# Epoch 62/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.5968 - iou_score: 15.3547 - val_loss: -54.1171 - val_iou_score: 10.1483
# Epoch 63/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.4346 - iou_score: 15.2797 - val_loss: -57.3287 - val_iou_score: 13.0235
# Epoch 64/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.6765 - iou_score: 15.4221 - val_loss: -57.4125 - val_iou_score: 13.0935
# Epoch 65/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.9242 - iou_score: 15.6286 - val_loss: -57.1888 - val_iou_score: 12.8440
# Epoch 66/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.8652 - iou_score: 15.6151 - val_loss: -55.5385 - val_iou_score: 12.7857
# Epoch 67/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.6936 - iou_score: 15.4921 - val_loss: -45.8328 - val_iou_score: 11.6413
# Epoch 68/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.3433 - iou_score: 15.1835 - val_loss: -56.2677 - val_iou_score: 12.9312
# Epoch 69/100
# 380/380 [==============================] - 4s 11ms/step - loss: -76.9752 - iou_score: 14.9004 - val_loss: -57.2455 - val_iou_score: 13.0567
# Epoch 70/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.6595 - iou_score: 15.4338 - val_loss: -56.7505 - val_iou_score: 12.5093
# Epoch 71/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.5976 - iou_score: 15.4374 - val_loss: -57.2757 - val_iou_score: 12.9362
# Epoch 72/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.9457 - iou_score: 15.6059 - val_loss: -57.3612 - val_iou_score: 13.1401
# Epoch 73/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.3468 - iou_score: 15.2590 - val_loss: -57.2849 - val_iou_score: 13.0590
# Epoch 74/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.8320 - iou_score: 15.5765 - val_loss: -57.5271 - val_iou_score: 13.3627
# Epoch 75/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.5872 - iou_score: 15.3335 - val_loss: -57.6507 - val_iou_score: 13.3824
# Epoch 76/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.8539 - iou_score: 15.6023 - val_loss: -57.0604 - val_iou_score: 13.0095
# Epoch 77/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.8729 - iou_score: 15.6629 - val_loss: -57.6607 - val_iou_score: 13.3042
# Epoch 78/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.6472 - iou_score: 15.4190 - val_loss: -57.5078 - val_iou_score: 13.1825
# Epoch 79/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.8591 - iou_score: 15.6040 - val_loss: -57.7306 - val_iou_score: 13.4193
# Epoch 80/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.9352 - iou_score: 15.6453 - val_loss: -57.8305 - val_iou_score: 13.4746
# Epoch 81/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.7898 - iou_score: 15.5178 - val_loss: -57.4872 - val_iou_score: 13.2300
# Epoch 82/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.7608 - iou_score: 15.5353 - val_loss: -57.6883 - val_iou_score: 13.3567
# Epoch 83/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.1524 - iou_score: 15.8235 - val_loss: -57.6424 - val_iou_score: 13.4747
# Epoch 84/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.0465 - iou_score: 15.7531 - val_loss: -57.7704 - val_iou_score: 13.4599
# Epoch 85/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.0235 - iou_score: 15.7490 - val_loss: -57.7152 - val_iou_score: 13.4181
# Epoch 86/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.0308 - iou_score: 15.7700 - val_loss: -57.3728 - val_iou_score: 13.2921
# Epoch 87/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.9911 - iou_score: 15.7172 - val_loss: -57.6116 - val_iou_score: 13.4029
# Epoch 88/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.9015 - iou_score: 15.5773 - val_loss: -57.4609 - val_iou_score: 13.3651
# Epoch 89/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.5853 - iou_score: 15.5173 - val_loss: -57.8088 - val_iou_score: 13.4597
# Epoch 90/100
# 380/380 [==============================] - 4s 12ms/step - loss: -77.7639 - iou_score: 15.4377 - val_loss: -57.7410 - val_iou_score: 13.3845
# Epoch 91/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.8631 - iou_score: 15.6044 - val_loss: -57.5984 - val_iou_score: 13.3196
# Epoch 92/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.0974 - iou_score: 15.8129 - val_loss: -57.6518 - val_iou_score: 13.3566
# Epoch 93/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.2968 - iou_score: 15.9107 - val_loss: -57.6849 - val_iou_score: 13.3253
# Epoch 94/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.3035 - iou_score: 15.9474 - val_loss: -57.4748 - val_iou_score: 13.1699
# Epoch 95/100
# 380/380 [==============================] - 4s 11ms/step - loss: -78.2365 - iou_score: 15.9017 - val_loss: -57.7241 - val_iou_score: 13.4133
# Epoch 96/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.2017 - iou_score: 15.1224 - val_loss: -42.6230 - val_iou_score: 7.6488
# Epoch 97/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.1337 - iou_score: 15.0308 - val_loss: -55.3792 - val_iou_score: 11.9843
# Epoch 98/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.4138 - iou_score: 15.2559 - val_loss: -54.4496 - val_iou_score: 12.3370
# Epoch 99/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.5418 - iou_score: 15.4204 - val_loss: -57.4869 - val_iou_score: 13.1984
# Epoch 100/100
# 380/380 [==============================] - 4s 11ms/step - loss: -77.6446 - iou_score: 15.4025 - val_loss: -57.3019 - val_iou_score: 13.0268

# %%
inim = X[42][:256,:256]
print(inim.shape,inim.dtype,np.min(inim),np.max(inim))
img=X[42][np.newaxis,:256,:256,np.newaxis]
pred = kmodel.predict(img)[0,:,:,0]
print(pred.shape)



fig, ax = plt.subplots(1,2, figsize=(12,6))

for a,d,cm,s in zip(ax.flat, [inim,pred], ['gray','magma'],
                    ['Input image','Predicted object probability']):
    a.imshow(d,cmap=cm)
    a.set_title(s)
    a.axis('off')
plt.tight_layout()
None;
# Out:
# (256, 256) float32 -0.022727273 1.2045455
# (256, 256)

# %%
from foolbox.models import KerasModel


fmodel = KerasModel(kmodel,bounds=(-1., 2.))

# %%
from foolbox.criteria import Criterion 
import math

class Missegmentation(Criterion):
    """Defines adversarials as inputs for which the predicted class
    is not the original class.
    See Also
    --------
    :class:`TopKMisclassification`
    Notes
    -----
    Uses `numpy.argmax` to break ties.
    """
    def __init__(self, cut=1e-5):
        super(Missegmentation, self).__init__()
        assert cut > 0
        self.t = cut
        
    def name(self):
        return 'Top1Missegmentation'

    #def is_adversarial(self, predictions, label):
    #    top1 = np.argmax(predictions)
    #    return top1 != label
    def is_adversarial(self, predictions, label):
        l2 = np.sum((pred-label)**2)
        return math.sqrt(l2) > self.t

# %%
#base_model.summary()
kmodel.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# data (InputLayer)               (None, None, None, 1 0
# __________________________________________________________________________________________________
# bn_data (BatchNormalization)    (None, None, None, 1 3           data[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_103 (ZeroPadding (None, None, None, 1 0           bn_data[0][0]
# __________________________________________________________________________________________________
# conv0 (Conv2D)                  (None, None, None, 6 3136        zero_padding2d_103[0][0]
# __________________________________________________________________________________________________
# bn0 (BatchNormalization)        (None, None, None, 6 256         conv0[0][0]
# __________________________________________________________________________________________________
# relu0 (Activation)              (None, None, None, 6 0           bn0[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_104 (ZeroPadding (None, None, None, 6 0           relu0[0][0]
# __________________________________________________________________________________________________
# pooling0 (MaxPooling2D)         (None, None, None, 6 0           zero_padding2d_104[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn1 (BatchNormaliz (None, None, None, 6 256         pooling0[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu1 (Activation) (None, None, None, 6 0           stage1_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_105 (ZeroPadding (None, None, None, 6 0           stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv1 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_105[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_relu2 (Activation) (None, None, None, 6 0           stage1_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_106 (ZeroPadding (None, None, None, 6 0           stage1_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_106[0][0]
# __________________________________________________________________________________________________
# stage1_unit1_sc (Conv2D)        (None, None, None, 6 4096        stage1_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_49 (Add)                    (None, None, None, 6 0           stage1_unit1_conv2[0][0]
#                                                                  stage1_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn1 (BatchNormaliz (None, None, None, 6 256         add_49[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu1 (Activation) (None, None, None, 6 0           stage1_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_107 (ZeroPadding (None, None, None, 6 0           stage1_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv1 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_107[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_relu2 (Activation) (None, None, None, 6 0           stage1_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_108 (ZeroPadding (None, None, None, 6 0           stage1_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit2_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_108[0][0]
# __________________________________________________________________________________________________
# add_50 (Add)                    (None, None, None, 6 0           stage1_unit2_conv2[0][0]
#                                                                  add_49[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn1 (BatchNormaliz (None, None, None, 6 256         add_50[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu1 (Activation) (None, None, None, 6 0           stage1_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_109 (ZeroPadding (None, None, None, 6 0           stage1_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv1 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_109[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_bn2 (BatchNormaliz (None, None, None, 6 256         stage1_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_relu2 (Activation) (None, None, None, 6 0           stage1_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_110 (ZeroPadding (None, None, None, 6 0           stage1_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage1_unit3_conv2 (Conv2D)     (None, None, None, 6 36864       zero_padding2d_110[0][0]
# __________________________________________________________________________________________________
# add_51 (Add)                    (None, None, None, 6 0           stage1_unit3_conv2[0][0]
#                                                                  add_50[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn1 (BatchNormaliz (None, None, None, 6 256         add_51[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu1 (Activation) (None, None, None, 6 0           stage2_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_111 (ZeroPadding (None, None, None, 6 0           stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv1 (Conv2D)     (None, None, None, 1 73728       zero_padding2d_111[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_relu2 (Activation) (None, None, None, 1 0           stage2_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_112 (ZeroPadding (None, None, None, 1 0           stage2_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_112[0][0]
# __________________________________________________________________________________________________
# stage2_unit1_sc (Conv2D)        (None, None, None, 1 8192        stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_52 (Add)                    (None, None, None, 1 0           stage2_unit1_conv2[0][0]
#                                                                  stage2_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn1 (BatchNormaliz (None, None, None, 1 512         add_52[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu1 (Activation) (None, None, None, 1 0           stage2_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_113 (ZeroPadding (None, None, None, 1 0           stage2_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv1 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_113[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_relu2 (Activation) (None, None, None, 1 0           stage2_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_114 (ZeroPadding (None, None, None, 1 0           stage2_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit2_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_114[0][0]
# __________________________________________________________________________________________________
# add_53 (Add)                    (None, None, None, 1 0           stage2_unit2_conv2[0][0]
#                                                                  add_52[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn1 (BatchNormaliz (None, None, None, 1 512         add_53[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu1 (Activation) (None, None, None, 1 0           stage2_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_115 (ZeroPadding (None, None, None, 1 0           stage2_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv1 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_115[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_relu2 (Activation) (None, None, None, 1 0           stage2_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_116 (ZeroPadding (None, None, None, 1 0           stage2_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit3_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_116[0][0]
# __________________________________________________________________________________________________
# add_54 (Add)                    (None, None, None, 1 0           stage2_unit3_conv2[0][0]
#                                                                  add_53[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn1 (BatchNormaliz (None, None, None, 1 512         add_54[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu1 (Activation) (None, None, None, 1 0           stage2_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_117 (ZeroPadding (None, None, None, 1 0           stage2_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv1 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_117[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_bn2 (BatchNormaliz (None, None, None, 1 512         stage2_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_relu2 (Activation) (None, None, None, 1 0           stage2_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_118 (ZeroPadding (None, None, None, 1 0           stage2_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage2_unit4_conv2 (Conv2D)     (None, None, None, 1 147456      zero_padding2d_118[0][0]
# __________________________________________________________________________________________________
# add_55 (Add)                    (None, None, None, 1 0           stage2_unit4_conv2[0][0]
#                                                                  add_54[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn1 (BatchNormaliz (None, None, None, 1 512         add_55[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu1 (Activation) (None, None, None, 1 0           stage3_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_119 (ZeroPadding (None, None, None, 1 0           stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv1 (Conv2D)     (None, None, None, 2 294912      zero_padding2d_119[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_relu2 (Activation) (None, None, None, 2 0           stage3_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_120 (ZeroPadding (None, None, None, 2 0           stage3_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_120[0][0]
# __________________________________________________________________________________________________
# stage3_unit1_sc (Conv2D)        (None, None, None, 2 32768       stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_56 (Add)                    (None, None, None, 2 0           stage3_unit1_conv2[0][0]
#                                                                  stage3_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn1 (BatchNormaliz (None, None, None, 2 1024        add_56[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu1 (Activation) (None, None, None, 2 0           stage3_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_121 (ZeroPadding (None, None, None, 2 0           stage3_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_121[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_relu2 (Activation) (None, None, None, 2 0           stage3_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_122 (ZeroPadding (None, None, None, 2 0           stage3_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit2_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_122[0][0]
# __________________________________________________________________________________________________
# add_57 (Add)                    (None, None, None, 2 0           stage3_unit2_conv2[0][0]
#                                                                  add_56[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn1 (BatchNormaliz (None, None, None, 2 1024        add_57[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu1 (Activation) (None, None, None, 2 0           stage3_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_123 (ZeroPadding (None, None, None, 2 0           stage3_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_123[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_relu2 (Activation) (None, None, None, 2 0           stage3_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_124 (ZeroPadding (None, None, None, 2 0           stage3_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit3_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_124[0][0]
# __________________________________________________________________________________________________
# add_58 (Add)                    (None, None, None, 2 0           stage3_unit3_conv2[0][0]
#                                                                  add_57[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn1 (BatchNormaliz (None, None, None, 2 1024        add_58[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu1 (Activation) (None, None, None, 2 0           stage3_unit4_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_125 (ZeroPadding (None, None, None, 2 0           stage3_unit4_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_125[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit4_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_relu2 (Activation) (None, None, None, 2 0           stage3_unit4_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_126 (ZeroPadding (None, None, None, 2 0           stage3_unit4_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit4_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_126[0][0]
# __________________________________________________________________________________________________
# add_59 (Add)                    (None, None, None, 2 0           stage3_unit4_conv2[0][0]
#                                                                  add_58[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn1 (BatchNormaliz (None, None, None, 2 1024        add_59[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu1 (Activation) (None, None, None, 2 0           stage3_unit5_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_127 (ZeroPadding (None, None, None, 2 0           stage3_unit5_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_127[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit5_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_relu2 (Activation) (None, None, None, 2 0           stage3_unit5_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_128 (ZeroPadding (None, None, None, 2 0           stage3_unit5_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit5_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_128[0][0]
# __________________________________________________________________________________________________
# add_60 (Add)                    (None, None, None, 2 0           stage3_unit5_conv2[0][0]
#                                                                  add_59[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn1 (BatchNormaliz (None, None, None, 2 1024        add_60[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu1 (Activation) (None, None, None, 2 0           stage3_unit6_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_129 (ZeroPadding (None, None, None, 2 0           stage3_unit6_relu1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv1 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_129[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_bn2 (BatchNormaliz (None, None, None, 2 1024        stage3_unit6_conv1[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_relu2 (Activation) (None, None, None, 2 0           stage3_unit6_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_130 (ZeroPadding (None, None, None, 2 0           stage3_unit6_relu2[0][0]
# __________________________________________________________________________________________________
# stage3_unit6_conv2 (Conv2D)     (None, None, None, 2 589824      zero_padding2d_130[0][0]
# __________________________________________________________________________________________________
# add_61 (Add)                    (None, None, None, 2 0           stage3_unit6_conv2[0][0]
#                                                                  add_60[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn1 (BatchNormaliz (None, None, None, 2 1024        add_61[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu1 (Activation) (None, None, None, 2 0           stage4_unit1_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_131 (ZeroPadding (None, None, None, 2 0           stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv1 (Conv2D)     (None, None, None, 5 1179648     zero_padding2d_131[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit1_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_relu2 (Activation) (None, None, None, 5 0           stage4_unit1_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_132 (ZeroPadding (None, None, None, 5 0           stage4_unit1_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_132[0][0]
# __________________________________________________________________________________________________
# stage4_unit1_sc (Conv2D)        (None, None, None, 5 131072      stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# add_62 (Add)                    (None, None, None, 5 0           stage4_unit1_conv2[0][0]
#                                                                  stage4_unit1_sc[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn1 (BatchNormaliz (None, None, None, 5 2048        add_62[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu1 (Activation) (None, None, None, 5 0           stage4_unit2_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_133 (ZeroPadding (None, None, None, 5 0           stage4_unit2_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv1 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_133[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit2_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_relu2 (Activation) (None, None, None, 5 0           stage4_unit2_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_134 (ZeroPadding (None, None, None, 5 0           stage4_unit2_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit2_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_134[0][0]
# __________________________________________________________________________________________________
# add_63 (Add)                    (None, None, None, 5 0           stage4_unit2_conv2[0][0]
#                                                                  add_62[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn1 (BatchNormaliz (None, None, None, 5 2048        add_63[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu1 (Activation) (None, None, None, 5 0           stage4_unit3_bn1[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_135 (ZeroPadding (None, None, None, 5 0           stage4_unit3_relu1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv1 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_135[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_bn2 (BatchNormaliz (None, None, None, 5 2048        stage4_unit3_conv1[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_relu2 (Activation) (None, None, None, 5 0           stage4_unit3_bn2[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_136 (ZeroPadding (None, None, None, 5 0           stage4_unit3_relu2[0][0]
# __________________________________________________________________________________________________
# stage4_unit3_conv2 (Conv2D)     (None, None, None, 5 2359296     zero_padding2d_136[0][0]
# __________________________________________________________________________________________________
# add_64 (Add)                    (None, None, None, 5 0           stage4_unit3_conv2[0][0]
#                                                                  add_63[0][0]
# __________________________________________________________________________________________________
# bn1 (BatchNormalization)        (None, None, None, 5 2048        add_64[0][0]
# __________________________________________________________________________________________________
# relu1 (Activation)              (None, None, None, 5 0           bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_upsample (UpSamp (None, None, None, 5 0           relu1[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, None, None, 7 0           decoder_stage0_upsample[0][0]
#                                                                  stage4_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv1 (Conv2D)   (None, None, None, 2 1769472     concatenate_13[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_bn1 (BatchNormal (None, None, None, 2 1024        decoder_stage0_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu1 (Activatio (None, None, None, 2 0           decoder_stage0_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_conv2 (Conv2D)   (None, None, None, 2 589824      decoder_stage0_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_bn2 (BatchNormal (None, None, None, 2 1024        decoder_stage0_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage0_relu2 (Activatio (None, None, None, 2 0           decoder_stage0_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_upsample (UpSamp (None, None, None, 2 0           decoder_stage0_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, None, None, 3 0           decoder_stage1_upsample[0][0]
#                                                                  stage3_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv1 (Conv2D)   (None, None, None, 1 442368      concatenate_14[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_bn1 (BatchNormal (None, None, None, 1 512         decoder_stage1_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu1 (Activatio (None, None, None, 1 0           decoder_stage1_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_conv2 (Conv2D)   (None, None, None, 1 147456      decoder_stage1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_bn2 (BatchNormal (None, None, None, 1 512         decoder_stage1_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage1_relu2 (Activatio (None, None, None, 1 0           decoder_stage1_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_upsample (UpSamp (None, None, None, 1 0           decoder_stage1_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, None, None, 1 0           decoder_stage2_upsample[0][0]
#                                                                  stage2_unit1_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv1 (Conv2D)   (None, None, None, 6 110592      concatenate_15[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_bn1 (BatchNormal (None, None, None, 6 256         decoder_stage2_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu1 (Activatio (None, None, None, 6 0           decoder_stage2_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_conv2 (Conv2D)   (None, None, None, 6 36864       decoder_stage2_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_bn2 (BatchNormal (None, None, None, 6 256         decoder_stage2_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage2_relu2 (Activatio (None, None, None, 6 0           decoder_stage2_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_upsample (UpSamp (None, None, None, 6 0           decoder_stage2_relu2[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, None, None, 1 0           decoder_stage3_upsample[0][0]
#                                                                  relu0[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv1 (Conv2D)   (None, None, None, 3 36864       concatenate_16[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_bn1 (BatchNormal (None, None, None, 3 128         decoder_stage3_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu1 (Activatio (None, None, None, 3 0           decoder_stage3_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_conv2 (Conv2D)   (None, None, None, 3 9216        decoder_stage3_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_bn2 (BatchNormal (None, None, None, 3 128         decoder_stage3_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage3_relu2 (Activatio (None, None, None, 3 0           decoder_stage3_bn2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_upsample (UpSamp (None, None, None, 3 0           decoder_stage3_relu2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv1 (Conv2D)   (None, None, None, 1 4608        decoder_stage4_upsample[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_bn1 (BatchNormal (None, None, None, 1 64          decoder_stage4_conv1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu1 (Activatio (None, None, None, 1 0           decoder_stage4_bn1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_conv2 (Conv2D)   (None, None, None, 1 2304        decoder_stage4_relu1[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_bn2 (BatchNormal (None, None, None, 1 64          decoder_stage4_conv2[0][0]
# __________________________________________________________________________________________________
# decoder_stage4_relu2 (Activatio (None, None, None, 1 0           decoder_stage4_bn2[0][0]
# __________________________________________________________________________________________________
# final_conv (Conv2D)             (None, None, None, 1 145         decoder_stage4_relu2[0][0]
# __________________________________________________________________________________________________
# sigmoid (Activation)            (None, None, None, 1 0           final_conv[0][0]
# ==================================================================================================
# Total params: 24,449,876
# Trainable params: 24,432,530
# Non-trainable params: 17,346
# __________________________________________________________________________________________________

# %%
from foolbox.adversarial import Adversarial
from foolbox.attacks import SinglePixelAttack

lab = Y[42][np.newaxis,:256,:256,np.newaxis]

attack = SinglePixelAttack()
criterion = Missegmentation()

adversarial = Adversarial(fmodel, criterion, img, lab)
fpred = attack(adversarial)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-62-3fef64ab5133> in <module>
#       3 lab = Y[42][np.newaxis,:256,:256,np.newaxis]
#       4
# ----> 5 adversarial = Adversarial(fmodel, criterion, img, lab)
#       6 fpred = attack(adversarial)
#
# /projects/steinbac/software/foolbox/repo/foolbox/adversarial.py in __init__(self, model, criterion, unperturbed, original_class, distance, threshold, verbose)
#      84
#      85         # check if the original input is already adversarial
# ---> 86         self._check_unperturbed()
#      87
#      88     def _check_unperturbed(self):
#
# /projects/steinbac/software/foolbox/repo/foolbox/adversarial.py in _check_unperturbed(self)
#      88     def _check_unperturbed(self):
#      89         try:
# ---> 90             self.forward_one(self.__unperturbed)
#      91         except StopAttack:
#      92             # if a threshold is specified and the unperturbed input is
#
# /projects/steinbac/software/foolbox/repo/foolbox/adversarial.py in forward_one(self, x, strict, return_details)
#     311
#     312         self._total_prediction_calls += 1
# --> 313         predictions = self.__model.forward_one(x)
#     314         is_adversarial, is_best, distance = self.__is_adversarial(
#     315             x, predictions, in_bounds)
#
# /projects/steinbac/software/foolbox/repo/foolbox/models/base.py in forward_one(self, x)
#     156
#     157         """
# --> 158         return np.squeeze(self.forward(x[np.newaxis]), axis=0)
#     159
#     160     @abstractmethod
#
# /projects/steinbac/software/foolbox/repo/foolbox/models/keras.py in forward(self, inputs)
#     100     def forward(self, inputs):
#     101         print(f"{__file__}:forward\t {inputs.shape}")
# --> 102         pinputs_ = self._process_input(inputs)
#     103         print(f"{__file__}:forward\t {pinputs_.shape}")
#     104         px, _ = pinputs_
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2713                 return self._legacy_call(inputs)
#    2714
# -> 2715             return self._call(inputs)
#    2716         else:
#    2717             if py_any(is_tensor(x) for x in inputs):
#
# ~/.local/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2673             fetched = self._callable_fn(*array_vals, run_metadata=self.run_metadata)
#    2674         else:
# -> 2675             fetched = self._callable_fn(*array_vals)
#    2676         return fetched[:len(self.outputs)]
#    2677
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1437           ret = tf_session.TF_SessionRunCallable(
#    1438               self._session._session, self._handle, args, status,
# -> 1439               run_metadata_ptr)
#    1440         if run_metadata:
#    1441           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/.local/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     526             None, None,
#     527             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 528             c_api.TF_GetCode(self.status.status))
#     529     # Delete the underlying status object from memory otherwise it stays alive
#     530     # as there is a reference to status from this from the traceback due to
#
# InvalidArgumentError: transpose expects a vector of size 5. But input(1) is a vector of size 4
# 	 [[{{node bn_data_3/FusedBatchNorm-0-TransposeNHWCToNCHW-LayoutOptimizer}}]]
# 	 [[{{node bn_data/keras_learning_phase}}]]
